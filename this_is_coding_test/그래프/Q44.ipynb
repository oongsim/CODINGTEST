# %% [markdown]
# # 행성 터널
# ---
# 입력예시<br>
# 5<br>
# 11 -15 -15<br>
# 14 -5 -15<br>
# -1 -1 -5<br>
# 10 -4 -1<br>
# 19 -4 19<br>
# <br>
# 출력예시<br>
# 4<br>
# <br><br>

# %%
# 조합 이용
from itertools import combinations

def find_parent(parent,a):
    if parent[a] != a: # 루트노드가 아니라면
        parent[a] = find_parent(parent, parent[a])
    return parent[a]

def union_parent(parent,a,b):
    a = find_parent(parent,a)
    b = find_parent(parent,b)
    if a > b:
        parent[a] = b
    else:
        parent[b] = a

n = int(input())
parent = [i for i in range(n)]

planets = []
for _ in range(n):
    planets.append(list(map(int,input().split()))) # planets 리스트에 행성 정보 담음 
    
idx = list(combinations(range(n),2)) # 행성 2개 묶기
edges = []
for i in idx: # i는 (행성1, 행성2)
    distance = min(abs(planets[i[0]][0]-planets[i[1]][0]),abs(planets[i[0]][1]-planets[i[1]][1]),abs(planets[i[0]][2]-planets[i[1]][2]))
    edges.append((distance, i[0], i[1])) # (거리, 행성1, 행성2)
edges.sort() # 거리순정렬

result = 0
cnt = 0
for edge in edges:
    cost,a,b = edge
    if find_parent(parent,a) != find_parent(parent,b): # 사이클이 발생하지 않으면
        union_parent(parent,a,b)
        result += cost
        cnt += 1
        if cnt == n-1:
            break
            
print(result)
# Out:
# 5
# 11 -15 -15
# 14 -5 -15
# -1 -1 -5
# 10 -4 -1
# 19 -4 19
# 4

# %%
# n(n-1)/2 개의 간선을 확인해야 하므로 시간이 많이 소요 될 수 있음

n = int(input())
planets = []
for _ in range(n):
    planets.append(tuple(map(int,input().split()))) # 리스트에 튜플 형태로 저장
    
costs = []
for i in range(n):
    for j in range(i):
        c = min(abs(planets[i][0]-planets[j][0]), abs(planets[i][1]-planets[j][1]), abs(planets[i][2]-planets[j][2]))
        costs.append((c,i,j)) # 리스트에 (비용, 인덱스, 인덱스) 형태로 저장

costs.sort() # 정렬

parent = [i for i in range(n)] # 부모 리스트 초기화

def find_parent(parent,x):
    if parent[x] != x:
        parent[x] = find_parent(parent,parent[x])
    return parent[x]

def union_parent(parent,a,b):
    a = find_parent(parent,a)
    b = find_parent(parent,b)
    if a > b:
        parent[a] = b
    else:
        parent[b] = a
        
result = 0
for cost in costs:
    c,i,j = cost
    if find_parent(parent,i) != find_parent(parent,j):
        union_parent(parent,i,j)
        result += c

print(result)
# Out:
# 5
# 11 -15 -15
# 14 -5 -15
# -1 -1 -5
# 10 -4 -1
# 19 -4 19
# 4

# %%
# 책풀이
# x축, y축, z축 기준으로 각각 정렬을 수행한 후 각각 n-1개의 간선만 고려하면 최적의 솔루션을 찾을 수 있음

def find_parent(parent,x):
    if parent[x] != x:
        parent[x] = find_parent(parent,parent[x])
    return parent[x]

def union_parent(parent,a,b):
    a = find_parent(parent,a)
    b = find_parent(parent,b)
    if a < b:
        parent[b] = a
    else:
        parent[a] = b
        
n = int(input())
parent = [i for i in range(n+1)]

# 모든 간선을 담을 리스트와 최종 비용을 담을 변수
edges = []
result = 0

x = []
y = []
z = []

# 모든 노드에 대한 좌표 값 입력받기
for i in range(1,n+1):
    data = list(map(int,input().split()))
    x.append((data[0],i))
    y.append((data[1],i))
    z.append((data[2],i))

x.sort()
y.sort()
z.sort()

# 인접한 노드들로부터 간선 정보를 추출하여 정리
for i in range(n-1):
    # 비용순으로 정렬하기 위해서 튜플의 첫 번째 원소를 비용으로 설정
    edges.append((x[i+1][0] - x[i][0], x[i][1], x[i+1][1]))
    edges.append((y[i+1][0] - y[i][0], y[i][1], y[i+1][1]))
    edges.append((z[i+1][0] - z[i][0], z[i][1], z[i+1][1]))
    
# 간선을 비용순으로 정렬
edges.sort()

# 간선을 하나씩 확인하며,
for edge in edges:
    cost,a,b = edge
    if find_parent(parent,a) != find_parent(parent,b):
        union_parent(parent,a,b)
        result += cost
        
print(result)
# Out:
# 5
# 11 -15 -15
# 14 -5 -15
# -1 -1 -5
# 10 -4 -1
# 19 -4 19
# 4
